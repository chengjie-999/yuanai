# %%
import os

import numpy as np
import pandas as pd 
from pyecharts.charts import *
from pyecharts import options as opts
import seaborn as sns

# %%
from pyecharts.globals import CurrentConfig, OnlineHostType
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST

# %%
from utils.data_path import root_path

df = pd.read_excel(os.path.join(root_path(), 'data/user/from/订单明细.xlsx'))
df.head()
# Out:
#     订单编号   用户编号                交易时间  交易状态  数量     金额
# 0  A0001  U0001 2021-01-22 00:17:59  交易成功   2  279.0
# 1  A0002  U0002 2021-01-22 00:59:54  交易成功   2  217.5
# 2  A0003  U0003 2021-01-22 07:48:48  交易成功   2  291.0
# 3  A0004  U0004 2021-01-22 09:15:49  退款成功   2  126.0
# 4  A0005  U0005 2021-01-22 09:59:33  退款成功   2  111.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28832 entries, 0 to 28831
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   订单编号    28832 non-null  object
#  1   用户编号    28832 non-null  object
#  2   交易时间    28832 non-null  datetime64[ns]
#  3   交易状态    28832 non-null  object
#  4   数量      28832 non-null  int64
#  5   金额      28832 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df['交易状态'].unique()
# Out:
# array(['交易成功', '退款成功'], dtype=object)

# %%
df = df.loc[df['交易状态'] == '交易成功']

# %%
df = df[['用户编号', '交易时间', '金额']]

# %%
df.head(10)
# Out:
#      用户编号                交易时间     金额
# 0   U0001 2021-01-22 00:17:59  279.0
# 1   U0002 2021-01-22 00:59:54  217.5
# 2   U0003 2021-01-22 07:48:48  291.0
# 5   U0006 2021-01-22 10:00:07  295.5
# 6   U0007 2021-01-22 10:00:08  252.0
# 7   U0008 2021-01-22 10:00:11  181.5
# 8   U0009 2021-01-22 10:00:14  316.5
# 9   U0010 2021-01-22 11:41:02  255.0
# 10  U0011 2021-01-22 12:08:49  186.0
# 11  U0012 2021-01-22 12:22:16  370.5

# %% [markdown]
# # R(近期交易时间)

# %% [markdown]
# - 最近一次交易时间距离统计日期的天数

# %%
start_data = df['交易时间'].max()
start_data
# Out:
# Timestamp('2021-07-21 22:46:22.511000')

# %%
# 求每个用户最后一次交易时间
r = df.groupby('用户编号')['交易时间'].max().reset_index()
r.head()
# Out:
#     用户编号                交易时间
# 0  U0001 2021-01-22 00:17:59
# 1  U0002 2021-01-22 00:59:54
# 2  U0003 2021-01-22 07:48:48
# 3  U0005 2021-02-01 08:12:15
# 4  U0006 2021-02-01 23:19:23

# %%
r['R'] = (start_data-r['交易时间']).dt.days
r = r[['用户编号', 'R']]
r.head()
# Out:
#     用户编号    R
# 0  U0001  180
# 1  U0002  180
# 2  U0003  180
# 3  U0005  170
# 4  U0006  169

# %% [markdown]
# # F(交易频次)

# %% [markdown]
# - 当天多次交易仅计算一次

# %%
# 以用户编号分组对交易时间去重计数
# df.groupby('用户编号').agg(F=('交易日期', 'nunique')).reset_index()
f = df.groupby('用户编号', as_index=False).agg(F=('交易时间', 'nunique'))
f.head(10)
# Out:
#     用户编号  F
# 0  U0001  1
# 1  U0002  1
# 2  U0003  1
# 3  U0005  1
# 4  U0006  2
# 5  U0007  2
# 6  U0008  1
# 7  U0009  3
# 8  U0010  1
# 9  U0011  1

# %% [markdown]
# # M(交易金额)

# %%
m = df.groupby('用户编号', as_index=False).agg(M=('金额', 'sum'))
m.head()
# Out:
#     用户编号      M
# 0  U0001  279.0
# 1  U0002  217.5
# 2  U0003  291.0
# 3  U0005  108.0
# 4  U0006  651.0

# %% [markdown]
# # RFM合并

# %%
# merge(左右内外交叉)\join(左右内外)\concat(内外)
rfm = r.merge(f, on='用户编号').merge(m, on='用户编号')
rfm.head()
# pd.merge(r, f, on='用户编号')
# Out:
#     用户编号    R  F      M
# 0  U0001  180  1  279.0
# 1  U0002  180  1  217.5
# 2  U0003  180  1  291.0
# 3  U0005  170  1  108.0
# 4  U0006  169  2  651.0

# %% [markdown]
# # RFM均值

# %%
rfm['R'].skew()
# Out:
# -0.23496334677596645

# %%
# 越接近零越对称
# rfm['R'].skew()
# -0.23497860252734598
sns.kdeplot(x=rfm['R'])
# Out:
# <Axes: xlabel='R', ylabel='Density'>

# %%
rfm['F'].skew()
# 4.623659633018703
sns.kdeplot(x=rfm['F'])
# Out:
# <Axes: xlabel='F', ylabel='Density'>

# %%
rfm['M'].skew()
# 14.15870871182295
sns.kdeplot(x=rfm['M'])
# Out:
# <Axes: xlabel='M', ylabel='Density'>

# %%
rfm.describe().round(2)
# Out:
#               R         F         M
# count  25419.00  25419.00  25419.00
# mean      97.04      1.09    207.20
# std       58.45      0.34    144.89
# min        0.00      1.00     45.00
# 25%       37.00      1.00    114.00
# 50%      105.00      1.00    186.00
# 75%      154.00      1.00    286.50
# max      180.00     15.00   9136.50

# %%
# R指标的均值
AVG_R = rfm['R'].mean()
# F指标的均值
AVG_F = rfm['F'].mean()
# M指标的均值
AVG_M = rfm['M'].mean()

# %%
# 100\10\1用于分类
rfm['R_score'] = (rfm['R'] < AVG_R)*100
rfm['F_score'] = (rfm['F'] > AVG_F)*10
rfm['M_score'] = (rfm['M'] > AVG_M)*1

# %%
# 总分值
rfm['Total_score'] = rfm['R_score']+rfm['F_score']+rfm['M_score']
rfm.head()
# Out:
#     用户编号    R  F      M  R_score  F_score  M_score  Total_score
# 0  U0001  180  1  279.0        0        0        1            1
# 1  U0002  180  1  217.5        0        0        1            1
# 2  U0003  180  1  291.0        0        0        1            1
# 3  U0005  170  1  108.0        0        0        0            0
# 4  U0006  169  2  651.0        0       10        1           11

# %% [markdown]
# # 标签映射

# %%
rfm['Total_score'].unique()
# Out:
# array([  1,   0,  11, 111, 100,  10, 110, 101])

# %%
dct = {111: '重要价值',
       110: '一般价值',
       101: '重要发展',
       100: '一般发展',
       11: '重要保持',
       10: '一般保持',
       1: '重要挽留',
       0: '一般挽留'}

# %%
rfm['用户标签'] = rfm['Total_score'].map(dct)

# %%
rfm['用户标签'].unique()
# Out:
# array(['重要挽留', '一般挽留', '重要保持', '重要价值', '一般发展', '一般保持', '一般价值', '重要发展'],
#       dtype=object)

# %%
rfm.head()
# Out:
#     用户编号    R  F      M  R_score  F_score  M_score  Total_score  用户标签
# 0  U0001  180  1  279.0        0        0        1            1  重要挽留
# 1  U0002  180  1  217.5        0        0        1            1  重要挽留
# 2  U0003  180  1  291.0        0        0        1            1  重要挽留
# 3  U0005  170  1  108.0        0        0        0            0  一般挽留
# 4  U0006  169  2  651.0        0       10        1           11  重要保持

# %% [markdown]
# # 各类用户占比

# %%
cnt = rfm['用户标签'].value_counts().reset_index()
cnt
# Out:
#    用户标签  count
# 0  一般挽留   7768
# 1  一般发展   5936
# 2  重要挽留   5156
# 3  重要发展   4533
# 4  重要价值   1105
# 5  重要保持    567
# 6  一般价值    252
# 7  一般保持    102

# %%
# 各类用户的人数统计
cnt = rfm['用户标签'].value_counts().reset_index()
cnt.columns = ['用户标签', '人数']
cnt['人数占比'] = cnt['人数'] / cnt['人数'].sum()
cnt
# Out:
#    用户标签    人数      人数占比
# 0  一般挽留  7768  0.305598
# 1  一般发展  5936  0.233526
# 2  重要挽留  5156  0.202840
# 3  重要发展  4533  0.178331
# 4  重要价值  1105  0.043471
# 5  重要保持   567  0.022306
# 6  一般价值   252  0.009914
# 7  一般保持   102  0.004013

# %%
# 各类用户的金额统计
amt = rfm.groupby('用户标签', as_index=False)['M'].sum()
amt.columns = ['用户标签', '金额']
amt['金额占比'] = amt['金额'] / amt['金额'].sum()
amt
# Out:
#    用户标签         金额      金额占比
# 0  一般价值    38247.0  0.007262
# 1  一般保持    16194.0  0.003075
# 2  一般发展   695890.5  0.132128
# 3  一般挽留   888801.0  0.168756
# 4  重要价值   522940.5  0.099290
# 5  重要保持   244242.0  0.046374
# 6  重要发展  1337377.5  0.253927
# 7  重要挽留  1523080.5  0.289187

# %%
tb = pd.merge(cnt, amt, on='用户标签')
tb['人数占比'] = tb['人数占比'].apply(lambda x: '{:.2%}'.format(x))
tb['金额占比'] = tb['金额占比'].apply(lambda x: '{:.2%}'.format(x))
tb.sort_values(by=['金额', '人数'], ascending=[False, False], inplace=True)
tb
# Out:
#    用户标签    人数    人数占比         金额    金额占比
# 2  重要挽留  5156  20.28%  1523080.5  28.92%
# 3  重要发展  4533  17.83%  1337377.5  25.39%
# 0  一般挽留  7768  30.56%   888801.0  16.88%
# 1  一般发展  5936  23.35%   695890.5  13.21%
# 4  重要价值  1105   4.35%   522940.5   9.93%
# 5  重要保持   567   2.23%   244242.0   4.64%
# 6  一般价值   252   0.99%    38247.0   0.73%
# 7  一般保持   102   0.40%    16194.0   0.31%

# %%
del tb['金额占比']
tb
# Out:
#    用户标签    人数    人数占比         金额
# 2  重要挽留  5156  20.28%  1523080.5
# 3  重要发展  4533  17.83%  1337377.5
# 0  一般挽留  7768  30.56%   888801.0
# 1  一般发展  5936  23.35%   695890.5
# 4  重要价值  1105   4.35%   522940.5
# 5  重要保持   567   2.23%   244242.0
# 6  一般价值   252   0.99%    38247.0
# 7  一般保持   102   0.40%    16194.0

# %% [markdown]
# # 可视化

# %%
# 1. 验证tb数据格式（必须是列表嵌套列表）
print("金额数据格式：", tb[['用户标签', '金额']].values.tolist())
print("人数数据格式：", tb[['用户标签', '人数']].values.tolist())

# 2. 极简测试（用固定数据绘制单饼图，排除数据异常）
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.globals import CurrentConfig, NotebookType

CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK  # 强制用传统Notebook模式
test_pie = Pie()
test_pie.add("", [("高价值", 50), ("中价值", 30), ("低价值", 20)])
test_pie.load_javascript()
test_pie.render_notebook()
# Out:
# 金额数据格式： [['重要挽留', 1523080.5], ['重要发展', 1337377.5], ['一般挽留', 888801.0], ['一般发展', 695890.5], ['重要价值', 522940.5], ['重要保持', 244242.0], ['一般价值', 38247.0], ['一般保持', 16194.0]]
# 人数数据格式： [['重要挽留', 5156], ['重要发展', 4533], ['一般挽留', 7768], ['一般发展', 5936], ['重要价值', 1105], ['重要保持', 567], ['一般价值', 252], ['一般保持', 102]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'http://localhost:8888/nbextensions/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a9ab265281294e389077b585ad40e5a1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a9ab265281294e389077b585ad40e5a1 = echarts.init(
#                     document.getElementById('a9ab265281294e389077b585ad40e5a1'), 'white', {renderer: 'canvas'});
#                 var option_a9ab265281294e389077b585ad40e5a1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u9ad8\u4ef7\u503c",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u4e2d\u4ef7\u503c",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u4f4e\u4ef7\u503c",
#                     "value": 20
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ad8\u4ef7\u503c",
#                 "\u4e2d\u4ef7\u503c",
#                 "\u4f4e\u4ef7\u503c"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_a9ab265281294e389077b585ad40e5a1.setOption(option_a9ab265281294e389077b585ad40e5a1);
#         });
#     </script>

# %%
# 第一步：导入所有需要的模块（放在最前面，避免冲突）
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.globals import CurrentConfig, NotebookType

# 第二步：设置Notebook渲染模式（仅需配置一次）
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB  # 旧版PyCharm用JUPYTER_NOTEBOOK

# 第三步：执行你的绘图代码（完全保留你的逻辑）
pie = Pie(init_opts=opts.InitOpts(width='1100px', height='500px'))
pie.add(
    '交易金额',
    tb[['用户标签', '金额']].values.tolist(),
    radius=['20%', '70%'],
    center=['25%', '50%'],
    rosetype='radius'
)
pie.set_series_opts(label_opts=opts.LabelOpts(formatter='{b}{d}%'))
pie.add(
    '交易人数',
    tb[['用户标签', '人数']].values.tolist(),
    radius=['20%', '70%'],
    center=['75%', '50%'],
    rosetype='radius'
)

# 第四步：加载资源+渲染
pie.load_javascript()
pie.render('RFM模型分析.html')
pie.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#         <div id="e1c20e59212f491bb510f5ed0de3dec6" class="chart-container" style="width:1100px; height:500px;"></div>
#     <script>
#         var chart_e1c20e59212f491bb510f5ed0de3dec6 = echarts.init(
#             document.getElementById('e1c20e59212f491bb510f5ed0de3dec6'), 'white', {renderer: 'canvas'});
#         var option_e1c20e59212f491bb510f5ed0de3dec6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u4ea4\u6613\u91d1\u989d",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91cd\u8981\u633d\u7559",
#                     "value": 1523080.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u53d1\u5c55",
#                     "value": 1337377.5
#                 },
#                 {
#                     "name": "\u4e00\u822c\u633d\u7559",
#                     "value": 888801.0
#                 },
#                 {
#                     "name": "\u4e00\u822c\u53d1\u5c55",
#                     "value": 695890.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4ef7\u503c",
#                     "value": 522940.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4fdd\u6301",
#                     "value": 244242.0
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4ef7\u503c",
#                     "value": 38247.0
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4fdd\u6301",
#                     "value": 16194.0
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "70%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": "\u4ea4\u6613\u4eba\u6570",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91cd\u8981\u633d\u7559",
#                     "value": 5156
#                 },
#                 {
#                     "name": "\u91cd\u8981\u53d1\u5c55",
#                     "value": 4533
#                 },
#                 {
#                     "name": "\u4e00\u822c\u633d\u7559",
#                     "value": 7768
#                 },
#                 {
#                     "name": "\u4e00\u822c\u53d1\u5c55",
#                     "value": 5936
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4ef7\u503c",
#                     "value": 1105
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4fdd\u6301",
#                     "value": 567
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4ef7\u503c",
#                     "value": 252
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4fdd\u6301",
#                     "value": 102
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "70%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91cd\u8981\u633d\u7559",
#                 "\u91cd\u8981\u53d1\u5c55",
#                 "\u4e00\u822c\u633d\u7559",
#                 "\u4e00\u822c\u53d1\u5c55",
#                 "\u91cd\u8981\u4ef7\u503c",
#                 "\u91cd\u8981\u4fdd\u6301",
#                 "\u4e00\u822c\u4ef7\u503c",
#                 "\u4e00\u822c\u4fdd\u6301"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#         chart_e1c20e59212f491bb510f5ed0de3dec6.setOption(option_e1c20e59212f491bb510f5ed0de3dec6);
#     </script>
# </body>
# </html>

# %%
# 各区域的RFM模型分析
path = os.path.join(root_path(), 'data/user/from/用户信息.xlsx')
user = pd.read_excel(path)
user.head()
# Out:
#     用户编号  省份  区域  大区
# 0  U0001  上海  华东  南区
# 1  U0002  广东  中南  南区
# 2  U0003  山东  华东  南区
# 3  U0004  江苏  华东  南区
# 4  U0005  上海  华东  南区

# %%
rfm_user = rfm.merge(user, on='用户编号')[['用户编号', '用户标签', '区域', 'M']]
rfm_user.head()
# Out:
#     用户编号  用户标签  区域      M
# 0  U0001  重要挽留  华东  279.0
# 1  U0002  重要挽留  中南  217.5
# 2  U0003  重要挽留  华东  291.0
# 3  U0005  一般挽留  华东  108.0
# 4  U0006  重要保持  华东  651.0

# %%
# 各区域内各类用户的人数和金额统计
tb2 = rfm_user.groupby(['区域', '用户标签']).agg(人数=('用户编号', 'count'), 金额=('M', 'sum')).reset_index()
tb2.sort_values(['金额','人数'], ascending = [False, False], inplace = True)
tb2.head()
# Out:
#     区域  用户标签    人数        金额
# 23  华东  重要挽留  2280  672448.5
# 22  华东  重要发展  2041  604053.0
# 19  华东  一般挽留  3653  413959.5
# 15  中南  重要挽留  1156  343150.5
# 18  华东  一般发展  2749  325111.5

# %%
# 选项卡多图, 每个区域一个图表
tab = Tab()
for i in tb2['区域'].unique():
    # print(i)
    data = tb2[tb2['区域'] == i]
    pie = Pie(init_opts=opts.InitOpts(width='1100px', height='500px'))
    pie.add(
        '交易金额',
        data[['用户标签', '金额']].values.tolist(),
        radius=['20%', '70%'],
        # 第一项为宽度,第二项为高度
        center=['25%', '50%'],
        rosetype='radius'
    )
    pie.add(
        '交易人数',
        data[['用户标签', '人数']].values.tolist(),
        radius=['20%', '70%'],
        # 第一项为宽度,第二项为高度
        center=['75%', '50%'],
        rosetype='radius'
    )
    pie.set_series_opts(label_opts=opts.LabelOpts(formatter='{b}{d}%'))
    tab.add(pie, i)
tab.render('RFM模型分析-区域.html')
tab.render_notebook()
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, '7245531e198e470196b8588b65e8ca74')">华东</button>
#             <button class="tablinks" onclick="showChart(event, '9dc1ee5e7523424ab4bd1acc7a668740')">中南</button>
#             <button class="tablinks" onclick="showChart(event, 'ccdfb9cc03f94c92801c3e71e3337bc2')">华北</button>
#             <button class="tablinks" onclick="showChart(event, 'a8b6673ec34e45aba4add919cc896b8f')">西南</button>
#             <button class="tablinks" onclick="showChart(event, 'a007eb0584e142ff891e41677220c98c')">东北</button>
#             <button class="tablinks" onclick="showChart(event, 'c96b1c6937874b29b02149eaed595050')">西北</button>
#     </div>
#
#         <div id="7245531e198e470196b8588b65e8ca74" class="chart-container" style="width:1100px; height:500px;"></div>
#     <script>
#         var chart_7245531e198e470196b8588b65e8ca74 = echarts.init(
#             document.getElementById('7245531e198e470196b8588b65e8ca74'), 'white', {renderer: 'canvas'});
#         var option_7245531e198e470196b8588b65e8ca74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u4ea4\u6613\u91d1\u989d",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91cd\u8981\u633d\u7559",
#                     "value": 672448.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u53d1\u5c55",
#                     "value": 604053.0
#                 },
#                 {
#                     "name": "\u4e00\u822c\u633d\u7559",
#                     "value": 413959.5
#                 },
#                 {
#                     "name": "\u4e00\u822c\u53d1\u5c55",
#                     "value": 325111.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4ef7\u503c",
#                     "value": 248014.5
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4fdd\u6301",
#                     "value": 113872.5
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4ef7\u503c",
#                     "value": 17341.5
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4fdd\u6301",
#                     "value": 7899.0
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "70%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "pie",
#             "name": "\u4ea4\u6613\u4eba\u6570",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u91cd\u8981\u633d\u7559",
#                     "value": 2280
#                 },
#                 {
#                     "name": "\u91cd\u8981\u53d1\u5c55",
#                     "value": 2041
#                 },
#                 {
#                     "name": "\u4e00\u822c\u633d\u7559",
#                     "value": 3653
#                 },
#                 {
#                     "name": "\u4e00\u822c\u53d1\u5c55",
#                     "value": 2749
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4ef7\u503c",
#                     "value": 526
#                 },
#                 {
#                     "name": "\u91cd\u8981\u4fdd\u6301",
#                     "value": 267
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4ef7\u503c",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u4e00\u822c\u4fdd\u6301",
#                     "value": 50
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "70%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}{d}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u91cd\u8981\u633d\u7559",
#                 "\u91cd\u8981\u53d1\u5c55",
#                 "\u4e00\u822c\u633d\u7559",
#                 "\u4e00\u822c\u53d1\u5c55",
#                 "\u91cd\u8981\u4ef7\u503c",
#                 "\u91cd\u8981\u4fdd\u6301",
#                 "\u4e00\u822c\u4ef7\u503c",
#                 "\u4e00\u822c\u4fdd\u6301"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#         chart_7245531e198e470196b8588b65e8ca74.setOption(option_7245531e198e470196b8588b65e8ca74);
#     </script>
#         <div id="9dc1ee5e7523424ab4bd1acc7a668740" class="chart-container" style="width:1100px; height:500px;"></div>
#     <script>
#         var chart_9dc1ee5e7523424ab4bd1acc7a668740 = echarts.init(
#             document.getElementById('9dc1ee5e7523424ab4bd1acc7a668740'), 'white', {renderer: 'canvas'});
#         var option_9dc1ee5e7523424ab4bd1acc7a668740 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#
